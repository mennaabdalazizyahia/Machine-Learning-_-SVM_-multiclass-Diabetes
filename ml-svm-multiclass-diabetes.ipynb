# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/multiclass-diabetes-dataset/Multiclass Diabetes Dataset/Multiclass Diabetes Dataset.csv

# %%
data = pd.read_csv("/kaggle/input/multiclass-diabetes-dataset/Multiclass Diabetes Dataset/Multiclass Diabetes Dataset.csv")

# %%
data.head()
# Out:
#    Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  Class
# 0       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0      0
# 1       1   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0      0
# 2       1   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0      0
# 3       0   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4  21.0      0
# 4       0   50   2.0  50    4.0   3.6  1.3  0.9  2.1   0.6  24.0      0

# %%
data.isna().sum()
# Out:
# Gender    0
# AGE       0
# Urea      0
# Cr        0
# HbA1c     0
# Chol      0
# TG        0
# HDL       0
# LDL       0
# VLDL      0
# BMI       0
# Class     0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Gender    0
# AGE       0
# Urea      0
# Cr        0
# HbA1c     0
# Chol      0
# TG        0
# HDL       0
# LDL       0
# VLDL      0
# BMI       0
# Class     0
# dtype: int64

# %%
data.describe()
# Out:
#            Gender         AGE        Urea          Cr       HbA1c        Chol  \
# count  264.000000  264.000000  264.000000  264.000000  264.000000  264.000000
# mean     0.545455   49.522727    5.671515   85.806818    6.862727    4.594394
# std      0.498875   10.127301    4.002837   99.400047    2.544604    1.289062
# min      0.000000   25.000000    1.100000    6.000000    0.900000    0.000000
# 25%      0.000000   43.000000    3.600000   46.000000    5.000000    3.875000
# 50%      1.000000   50.000000    4.700000   61.000000    6.100000    4.500000
# 75%      1.000000   55.250000    6.100000   82.250000    8.200000    5.300000
# max      1.000000   77.000000   26.400000  800.000000   14.600000    9.500000
#
#                TG         HDL         LDL        VLDL         BMI       Class
# count  264.000000  264.000000  264.000000  264.000000  264.000000  264.000000
# mean     2.151894    1.182879    2.530871    1.479167   26.626856    1.121212
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  264 non-null    int64
#  1   AGE     264 non-null    int64
#  2   Urea    264 non-null    float64
#  3   Cr      264 non-null    int64
#  4   HbA1c   264 non-null    float64
#  5   Chol    264 non-null    float64
#  6   TG      264 non-null    float64
#  7   HDL     264 non-null    float64
#  8   LDL     264 non-null    float64
#  9   VLDL    264 non-null    float64
#  10  BMI     264 non-null    float64
#  11  Class   264 non-null    int64
# dtypes: float64(8), int64(4)
# memory usage: 24.9 KB

# %%
data['target'] = data.Class

# %%
data.head()
# Out:
#    Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  Class  \
# 0       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0      0
# 1       1   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0      0
# 2       1   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0      0
# 3       0   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4  21.0      0
# 4       0   50   2.0  50    4.0   3.6  1.3  0.9  2.1   0.6  24.0      0
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data.drop('Class',axis =1,inplace = True)

# %%
data.head()
# Out:
#    Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  target
# 0       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0       0
# 1       1   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0       0
# 2       1   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0       0
# 3       0   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4  21.0       0
# 4       0   50   2.0  50    4.0   3.6  1.3  0.9  2.1   0.6  24.0       0

# %%
data.target.value_counts()
# Out:
# target
# 2    128
# 0     96
# 1     40
# Name: count, dtype: int64

# %%
df0 = data[data.target == 0]
df1 = data[data.target == 1]
df2 = data[data.target == 2]

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel("Gender")
plt.ylabel("AGE")
plt.scatter(df0['Gender'],df0['AGE'],color = "green",marker = '+',label = data.target[0])
plt.scatter(df1['Gender'],df1['AGE'],color = "blue",marker = '.',label = data.target[1])
plt.scatter(df2['Gender'],df2['AGE'],color = "red",marker = '*',label = data.target[2])
plt.show()

# %%
x = data.drop('target',axis = 1)
y = data.target

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 259    2
# 260    2
# 261    2
# 262    2
# 263    2
# Name: target, Length: 264, dtype: int64

# %%
x
# Out:
#      Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI
# 0         0   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 1         1   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6  23.0
# 2         1   33   7.1   46    4.9   4.9  1.0  0.8  2.0   0.4  21.0
# 3         0   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4  21.0
# 4         0   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6  24.0
# ..      ...  ...   ...  ...    ...   ...  ...  ...  ...   ...   ...
# 259       0   61  24.0  401    7.0   4.3  2.9  0.4  2.7   1.3  30.0
# 260       0   61  24.0  401    7.0   4.3  2.9  0.4  2.7   1.3  36.6
# 261       1   60  20.8  800    9.0   2.3  1.1  0.9  0.9   0.5  33.0
# 262       1   56  20.8  800    9.0   4.6  2.0  1.2  2.5   0.9  35.0
# 263       1   58  20.8  800    9.1   6.6  2.9  1.1  4.3   1.3  33.0
#
# [264 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 42,test_size = 0.3)

# %%
x_train
# Out:
#      Gender  AGE  Urea   Cr  HbA1c  Chol   TG   HDL   LDL  VLDL   BMI
# 236       1   64   8.8  106    8.5   5.9  2.1  1.20  4.00   1.2  32.0
# 159       0   55   4.4   35   11.7   5.0  3.5  1.50  2.10   1.5  29.0
# 146       0   58   3.3   30   10.2   6.3  2.4  1.90  0.75   1.1  27.0
# 69        1   59   4.7   58    4.1   6.3  0.6  1.10  4.90   1.1  24.0
# 2         1   33   7.1   46    4.9   4.9  1.0  0.80  2.00   0.4  21.0
# ..      ...  ...   ...  ...    ...   ...  ...   ...   ...   ...   ...
# 20        1   50   4.0   28    5.3   4.8  1.0  0.90  3.60   0.4  23.0
# 188       0   69   6.1   49    8.2   8.0  4.8  1.30  4.80   2.2  34.0
# 71        1   51   4.5   88    4.0   4.1  1.5  0.90  2.70   1.1  20.0
# 106       0   49   3.3   44    6.0   5.6  1.9  0.75  1.35   0.8  21.0
# 102       1   50   4.3   59    6.1   4.0  3.0  1.00  1.80   1.3  24.0
#
# [184 rows x 11 columns]

# %%
x_test
# Out:
#      Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI
# 68        0   44   4.4   56    4.2   3.4  1.3  1.3  1.5   0.6  21.0
# 194       1   52   5.1   70    7.0   7.5  1.7  1.2  1.8   0.6  30.0
# 82        0   40   6.3   79    4.9   4.3  0.8  0.8  1.8   1.2  22.0
# 247       1   60  10.0  194    7.1   4.6  1.6  0.8  1.8   1.7  26.0
# 109       0   39   3.0   38    6.4   4.7  1.3  1.1  3.1   0.6  22.0
# ..      ...  ...   ...  ...    ...   ...  ...  ...  ...   ...   ...
# 170       0   59   4.7   55    7.0   3.4  1.8  1.1  1.8   0.8  26.0
# 120       0   49   4.6   60    6.1   4.8  1.4  0.7  3.9   1.7  25.0
# 126       0   40   2.1   52    5.9   2.1  2.3  0.9  2.8   1.2  30.0
# 141       0   44   4.0   32    4.3   5.3  1.8  0.9  3.6   0.9  25.0
# 86        0   60   7.5   70    0.9   3.4  5.3  1.1  3.6   0.8  24.0
#
# [80 rows x 11 columns]

# %%
y_train
# Out:
# 236    2
# 159    2
# 146    2
# 69     0
# 2      0
#       ..
# 20     0
# 188    2
# 71     0
# 106    1
# 102    1
# Name: target, Length: 184, dtype: int64

# %%
y_test
# Out:
# 68     0
# 194    2
# 82     0
# 247    2
# 109    1
#       ..
# 170    2
# 120    1
# 126    1
# 141    2
# 86     0
# Name: target, Length: 80, dtype: int64

# %%
from sklearn.svm import SVC
model = SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
model.score(x_train,y_train)
# Out:
# 0.7391304347826086

# %%
model.score(x_test,y_test)
# Out:
# 0.7625

# %%
#PARAMETER (REGULARIZATION )
model_reg0 = SVC(C = 0.1)
model_reg0.fit(x_train,y_train)
model_reg0.score(x_test,y_test)
# Out:
# 0.5

# %%
model_reg1 = SVC(C =1)
model_reg1.fit(x_train,y_train)
model_reg1.score(x_test,y_test)
# Out:
# 0.7625

# %%
model_reg2 = SVC(C = 1000)
model_reg2.fit(x_train,y_train)
model_reg2.score(x_test,y_test)
# Out:
# 0.9125

# %%
#PARAMETER (GAMMA)
model_gamma0 = SVC(gamma = 0.1)
model_gamma0.fit(x_train,y_train)
model_gamma0.score(x_test,y_test)
# Out:
# 0.675

# %%
model_gamma1 = SVC(gamma = 1)
model_gamma1.fit(x_train,y_train)
model_gamma1.score(x_test,y_test)
# Out:
# 0.525

# %%
model_gamma2 = SVC(gamma = 1000)
model_gamma2.fit(x_train,y_train)
model_gamma2.score(x_test,y_test)
# Out:
# 0.5

# %%
#PARAMETER (KERNEL)
model_linear = SVC(kernel = 'linear')
model_linear.fit(x_train,y_train)
model_linear.score(x_test,y_test)
# Out:
# 0.925

# %%
model_rbf = SVC(kernel = 'rbf')
model_rbf.fit(x_train,y_train)
model_rbf.score(x_test,y_test)
# Out:
# 0.7625
